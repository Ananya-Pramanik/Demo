# %%
# example of one hot encoding for a neural network
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from keras.models import Sequential
from keras.layers import Dense

# load the dataset
def load_dataset(filename):
	# load the dataset as a pandas DataFrame
	data = read_csv(filename, header=None)
	print(data.info())
	# retrieve numpy array
	dataset = data.values
	# split into input (X) and output (y) variables
	X = dataset[:, :-1]
	y = dataset[:,-1]
	# format all fields as string
	X = X.astype(str)
	# reshape target to be a 2d array
	y = y.reshape((len(y), 1))
	return X, y

# prepare input data
def prepare_inputs(X_train, X_test):
	ohe = OneHotEncoder()
	ohe.fit(X_train)
	X_train_enc = ohe.transform(X_train)
	X_test_enc = ohe.transform(X_test)
	return X_train_enc, X_test_enc

# prepare target
def prepare_targets(y_train, y_test):
	le = LabelEncoder()
	le.fit(y_train)
	y_train_enc = le.transform(y_train)
	y_test_enc = le.transform(y_test)
	return y_train_enc, y_test_enc

# load the dataset
X, y = load_dataset('breast-cancer.csv')
print(X.shape, y.shape)
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# prepare input data
X_train_enc, X_test_enc = prepare_inputs(X_train, X_test)
print(X_train_enc.shape, X_test_enc.shape)
# prepare output data
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)
print(y_train_enc.shape, y_test_enc.shape)
# define the  model
model = Sequential()
model.add(Dense(10, input_dim=X_train_enc.shape[1], activation='relu', kernel_initializer='he_normal'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(X_train_enc, y_train_enc, epochs=100, batch_size=16, verbose=2)
# evaluate the keras model
_, accuracy = model.evaluate(X_test_enc, y_test_enc, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286 entries, 0 to 285
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       286 non-null    object
#  1   1       286 non-null    object
#  2   2       286 non-null    object
#  3   3       286 non-null    object
#  4   4       278 non-null    object
#  5   5       286 non-null    object
#  6   6       286 non-null    object
#  7   7       285 non-null    object
#  8   8       286 non-null    object
#  9   9       286 non-null    object
# dtypes: object(10)
# memory usage: 22.5+ KB
# None
# (286, 9) (286, 1)
# (191, 9) (95, 9) (191, 1) (95, 1)
# (191, 43) (95, 43)
# (191,) (95,)
# Epoch 1/100
# /Users/ananya_pramanik/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/ananya_pramanik/opt/anaconda3/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/ananya_pramanik/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/indexed_slices.py:444: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("gradient_tape/sequential_3/dense_6/embedding_lookup_sparse/Reshape_1:0", shape=(None,), dtype=int32), values=Tensor("gradient_tape/sequential_3/dense_6/embedding_lookup_sparse/Reshape:0", shape=(None, 10), dtype=float32), dense_shape=Tensor("gradient_tape/sequential_3/dense_6/embedding_lookup_sparse/Cast:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   warnings.warn(
# 12/12 - 1s - loss: 0.6784 - accuracy: 0.5393 - 653ms/epoch - 54ms/step
# Epoch 2/100
# 12/12 - 0s - loss: 0.6442 - accuracy: 0.6649 - 31ms/epoch - 3ms/step
# Epoch 3/100
# 12/12 - 0s - loss: 0.6141 - accuracy: 0.7225 - 17ms/epoch - 1ms/step
# Epoch 4/100
# 12/12 - 0s - loss: 0.5926 - accuracy: 0.7330 - 20ms/epoch - 2ms/step
# Epoch 5/100
# 12/12 - 0s - loss: 0.5736 - accuracy: 0.7277 - 18ms/epoch - 2ms/step
# Epoch 6/100
# 12/12 - 0s - loss: 0.5614 - accuracy: 0.7277 - 27ms/epoch - 2ms/step
# Epoch 7/100
# 12/12 - 0s - loss: 0.5504 - accuracy: 0.7330 - 21ms/epoch - 2ms/step
# Epoch 8/100
# 12/12 - 0s - loss: 0.5414 - accuracy: 0.7330 - 21ms/epoch - 2ms/step
# Epoch 9/100
# 12/12 - 0s - loss: 0.5344 - accuracy: 0.7330 - 23ms/epoch - 2ms/step
# Epoch 10/100
# 12/12 - 0s - loss: 0.5277 - accuracy: 0.7330 - 27ms/epoch - 2ms/step
# Epoch 11/100
# 12/12 - 0s - loss: 0.5220 - accuracy: 0.7330 - 23ms/epoch - 2ms/step
# Epoch 12/100
# 12/12 - 0s - loss: 0.5164 - accuracy: 0.7330 - 24ms/epoch - 2ms/step
# Epoch 13/100
# 12/12 - 0s - loss: 0.5115 - accuracy: 0.7330 - 26ms/epoch - 2ms/step
# Epoch 14/100
# 12/12 - 0s - loss: 0.5067 - accuracy: 0.7382 - 19ms/epoch - 2ms/step
# Epoch 15/100
# 12/12 - 0s - loss: 0.5021 - accuracy: 0.7487 - 24ms/epoch - 2ms/step
# Epoch 16/100
# 12/12 - 0s - loss: 0.4975 - accuracy: 0.7487 - 24ms/epoch - 2ms/step
# Epoch 17/100
# 12/12 - 0s - loss: 0.4933 - accuracy: 0.7487 - 22ms/epoch - 2ms/step
# Epoch 18/100
# 12/12 - 0s - loss: 0.4896 - accuracy: 0.7644 - 24ms/epoch - 2ms/step
# Epoch 19/100
# 12/12 - 0s - loss: 0.4859 - accuracy: 0.7592 - 28ms/epoch - 2ms/step
# Epoch 20/100
# 12/12 - 0s - loss: 0.4823 - accuracy: 0.7644 - 29ms/epoch - 2ms/step
# Epoch 21/100
# 12/12 - 0s - loss: 0.4786 - accuracy: 0.7801 - 31ms/epoch - 3ms/step
# Epoch 22/100
# 12/12 - 0s - loss: 0.4749 - accuracy: 0.7749 - 30ms/epoch - 3ms/step
# Epoch 23/100
# 12/12 - 0s - loss: 0.4725 - accuracy: 0.7749 - 30ms/epoch - 3ms/step
# Epoch 24/100
# 12/12 - 0s - loss: 0.4694 - accuracy: 0.7696 - 25ms/epoch - 2ms/step
# Epoch 25/100
# 12/12 - 0s - loss: 0.4657 - accuracy: 0.7801 - 28ms/epoch - 2ms/step
# Epoch 26/100
# 12/12 - 0s - loss: 0.4629 - accuracy: 0.7853 - 26ms/epoch - 2ms/step
# Epoch 27/100
# 12/12 - 0s - loss: 0.4593 - accuracy: 0.7906 - 25ms/epoch - 2ms/step
# Epoch 28/100
# 12/12 - 0s - loss: 0.4563 - accuracy: 0.7958 - 30ms/epoch - 3ms/step
# Epoch 29/100
# 12/12 - 0s - loss: 0.4537 - accuracy: 0.7958 - 28ms/epoch - 2ms/step
# Epoch 30/100
# 12/12 - 0s - loss: 0.4512 - accuracy: 0.7958 - 23ms/epoch - 2ms/step
# Epoch 31/100
# 12/12 - 0s - loss: 0.4477 - accuracy: 0.8010 - 21ms/epoch - 2ms/step
# Epoch 32/100
# 12/12 - 0s - loss: 0.4449 - accuracy: 0.8010 - 28ms/epoch - 2ms/step
# Epoch 33/100
# 12/12 - 0s - loss: 0.4417 - accuracy: 0.7958 - 27ms/epoch - 2ms/step
# Epoch 34/100
# 12/12 - 0s - loss: 0.4390 - accuracy: 0.8010 - 24ms/epoch - 2ms/step
# Epoch 35/100
# 12/12 - 0s - loss: 0.4362 - accuracy: 0.8010 - 29ms/epoch - 2ms/step
# Epoch 36/100
# 12/12 - 0s - loss: 0.4331 - accuracy: 0.8010 - 30ms/epoch - 3ms/step
# Epoch 37/100
# 12/12 - 0s - loss: 0.4305 - accuracy: 0.8063 - 23ms/epoch - 2ms/step
# Epoch 38/100
# 12/12 - 0s - loss: 0.4278 - accuracy: 0.8063 - 20ms/epoch - 2ms/step
# Epoch 39/100
# 12/12 - 0s - loss: 0.4255 - accuracy: 0.8115 - 25ms/epoch - 2ms/step
# Epoch 40/100
# 12/12 - 0s - loss: 0.4221 - accuracy: 0.8115 - 28ms/epoch - 2ms/step
# Epoch 41/100
# 12/12 - 0s - loss: 0.4194 - accuracy: 0.8168 - 21ms/epoch - 2ms/step
# Epoch 42/100
# 12/12 - 0s - loss: 0.4165 - accuracy: 0.8168 - 25ms/epoch - 2ms/step
# Epoch 43/100
# 12/12 - 0s - loss: 0.4143 - accuracy: 0.8168 - 24ms/epoch - 2ms/step
# Epoch 44/100
# 12/12 - 0s - loss: 0.4117 - accuracy: 0.8168 - 37ms/epoch - 3ms/step
# Epoch 45/100
# 12/12 - 0s - loss: 0.4087 - accuracy: 0.8220 - 26ms/epoch - 2ms/step
# Epoch 46/100
# 12/12 - 0s - loss: 0.4062 - accuracy: 0.8272 - 26ms/epoch - 2ms/step
# Epoch 47/100
# 12/12 - 0s - loss: 0.4036 - accuracy: 0.8220 - 30ms/epoch - 3ms/step
# Epoch 48/100
# 12/12 - 0s - loss: 0.4012 - accuracy: 0.8272 - 28ms/epoch - 2ms/step
# Epoch 49/100
# 12/12 - 0s - loss: 0.3988 - accuracy: 0.8272 - 29ms/epoch - 2ms/step
# Epoch 50/100
# 12/12 - 0s - loss: 0.3963 - accuracy: 0.8272 - 25ms/epoch - 2ms/step
# Epoch 51/100
# 12/12 - 0s - loss: 0.3938 - accuracy: 0.8325 - 27ms/epoch - 2ms/step
# Epoch 52/100
# 12/12 - 0s - loss: 0.3917 - accuracy: 0.8325 - 30ms/epoch - 2ms/step
# Epoch 53/100
# 12/12 - 0s - loss: 0.3893 - accuracy: 0.8377 - 30ms/epoch - 2ms/step
# Epoch 54/100
# 12/12 - 0s - loss: 0.3869 - accuracy: 0.8482 - 39ms/epoch - 3ms/step
# Epoch 55/100
# 12/12 - 0s - loss: 0.3846 - accuracy: 0.8534 - 38ms/epoch - 3ms/step
# Epoch 56/100
# 12/12 - 0s - loss: 0.3817 - accuracy: 0.8534 - 43ms/epoch - 4ms/step
# Epoch 57/100
# 12/12 - 0s - loss: 0.3794 - accuracy: 0.8534 - 42ms/epoch - 3ms/step
# Epoch 58/100
# 12/12 - 0s - loss: 0.3771 - accuracy: 0.8586 - 48ms/epoch - 4ms/step
# Epoch 59/100
# 12/12 - 0s - loss: 0.3745 - accuracy: 0.8586 - 41ms/epoch - 3ms/step
# Epoch 60/100
# 12/12 - 0s - loss: 0.3727 - accuracy: 0.8586 - 42ms/epoch - 3ms/step
# Epoch 61/100
# 12/12 - 0s - loss: 0.3704 - accuracy: 0.8586 - 39ms/epoch - 3ms/step
# Epoch 62/100
# 12/12 - 0s - loss: 0.3682 - accuracy: 0.8639 - 34ms/epoch - 3ms/step
# Epoch 63/100
# 12/12 - 0s - loss: 0.3655 - accuracy: 0.8586 - 32ms/epoch - 3ms/step
# Epoch 64/100
# 12/12 - 0s - loss: 0.3632 - accuracy: 0.8691 - 26ms/epoch - 2ms/step
# Epoch 65/100
# 12/12 - 0s - loss: 0.3610 - accuracy: 0.8691 - 25ms/epoch - 2ms/step
# Epoch 66/100
# 12/12 - 0s - loss: 0.3590 - accuracy: 0.8691 - 29ms/epoch - 2ms/step
# Epoch 67/100
# 12/12 - 0s - loss: 0.3569 - accuracy: 0.8691 - 24ms/epoch - 2ms/step
# Epoch 68/100
# 12/12 - 0s - loss: 0.3546 - accuracy: 0.8639 - 25ms/epoch - 2ms/step
# Epoch 69/100
# 12/12 - 0s - loss: 0.3525 - accuracy: 0.8639 - 29ms/epoch - 2ms/step
# Epoch 70/100
# 12/12 - 0s - loss: 0.3504 - accuracy: 0.8639 - 26ms/epoch - 2ms/step
# Epoch 71/100
# 12/12 - 0s - loss: 0.3486 - accuracy: 0.8639 - 26ms/epoch - 2ms/step
# Epoch 72/100
# 12/12 - 0s - loss: 0.3459 - accuracy: 0.8639 - 41ms/epoch - 3ms/step
# Epoch 73/100
# 12/12 - 0s - loss: 0.3439 - accuracy: 0.8639 - 44ms/epoch - 4ms/step
# Epoch 74/100
# 12/12 - 0s - loss: 0.3419 - accuracy: 0.8639 - 51ms/epoch - 4ms/step
# Epoch 75/100
# 12/12 - 0s - loss: 0.3401 - accuracy: 0.8639 - 30ms/epoch - 3ms/step
# Epoch 76/100
# 12/12 - 0s - loss: 0.3383 - accuracy: 0.8586 - 21ms/epoch - 2ms/step
# Epoch 77/100
# 12/12 - 0s - loss: 0.3359 - accuracy: 0.8586 - 19ms/epoch - 2ms/step
# Epoch 78/100
# 12/12 - 0s - loss: 0.3341 - accuracy: 0.8586 - 21ms/epoch - 2ms/step
# Epoch 79/100
# 12/12 - 0s - loss: 0.3322 - accuracy: 0.8586 - 19ms/epoch - 2ms/step
# Epoch 80/100
# 12/12 - 0s - loss: 0.3304 - accuracy: 0.8586 - 23ms/epoch - 2ms/step
# Epoch 81/100
# 12/12 - 0s - loss: 0.3281 - accuracy: 0.8586 - 19ms/epoch - 2ms/step
# Epoch 82/100
# 12/12 - 0s - loss: 0.3267 - accuracy: 0.8586 - 23ms/epoch - 2ms/step
# Epoch 83/100
# 12/12 - 0s - loss: 0.3245 - accuracy: 0.8691 - 27ms/epoch - 2ms/step
# Epoch 84/100
# 12/12 - 0s - loss: 0.3230 - accuracy: 0.8691 - 32ms/epoch - 3ms/step
# Epoch 85/100
# 12/12 - 0s - loss: 0.3213 - accuracy: 0.8691 - 20ms/epoch - 2ms/step
# Epoch 86/100
# 12/12 - 0s - loss: 0.3192 - accuracy: 0.8691 - 20ms/epoch - 2ms/step
# Epoch 87/100
# 12/12 - 0s - loss: 0.3173 - accuracy: 0.8691 - 21ms/epoch - 2ms/step
# Epoch 88/100
# 12/12 - 0s - loss: 0.3158 - accuracy: 0.8691 - 14ms/epoch - 1ms/step
# Epoch 89/100
# 12/12 - 0s - loss: 0.3149 - accuracy: 0.8691 - 20ms/epoch - 2ms/step
# Epoch 90/100
# 12/12 - 0s - loss: 0.3120 - accuracy: 0.8743 - 29ms/epoch - 2ms/step
# Epoch 91/100
# 12/12 - 0s - loss: 0.3103 - accuracy: 0.8743 - 31ms/epoch - 3ms/step
# Epoch 92/100
# 12/12 - 0s - loss: 0.3089 - accuracy: 0.8743 - 26ms/epoch - 2ms/step
# Epoch 93/100
# 12/12 - 0s - loss: 0.3073 - accuracy: 0.8796 - 38ms/epoch - 3ms/step
# Epoch 94/100
# 12/12 - 0s - loss: 0.3056 - accuracy: 0.8743 - 40ms/epoch - 3ms/step
# Epoch 95/100
# 12/12 - 0s - loss: 0.3035 - accuracy: 0.8796 - 23ms/epoch - 2ms/step
# Epoch 96/100
# 12/12 - 0s - loss: 0.3021 - accuracy: 0.8796 - 26ms/epoch - 2ms/step
# Epoch 97/100
# 12/12 - 0s - loss: 0.3006 - accuracy: 0.8796 - 36ms/epoch - 3ms/step
# Epoch 98/100
# 12/12 - 0s - loss: 0.2987 - accuracy: 0.8796 - 30ms/epoch - 3ms/step
# Epoch 99/100
# 12/12 - 0s - loss: 0.2972 - accuracy: 0.8796 - 27ms/epoch - 2ms/step
# Epoch 100/100
# 12/12 - 0s - loss: 0.2956 - accuracy: 0.8796 - 25ms/epoch - 2ms/step
# Accuracy: 67.37
